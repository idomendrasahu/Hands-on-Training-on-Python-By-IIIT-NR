# %% [markdown]
# # **Using Google Colab to learn Python**

# %% [markdown]
# ## Revisiting Hello World

# %%
#Prints the Words “Hello World”
print("Hello World")

# Press Shift + Enter to execute any cell
# Out:
# Hello World

# %% [markdown]
# ## **Comment in the Code**
#
# Note, we have written the first line of code in the program as starting with a # symbol. This symbol tells the interpreter that the current line is a comment.
#
# Therefore,

# %%
#This is a comment
#This is also a comment
#This is yet another comment
# But this is not a comment
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# Alternatively, we can also use three single quotes (or three double quotes) for multiline comments, like this:

# %%
'''
This is a comment
This is also a comment
This is yet another comment
'''
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ## **Python Indentation**
#
# * Indentation refers to the spaces at the beginning of a code line.
# * Where in other programming languages the indentation in code is for readability only, the indentation in Python is very important.
# * Python uses indentation to indicate a block of code.

# %%
if 5 < 2:
    print("Five is greater than two!")
    print("Hello")
    print('My name is Dr. Muneendra Ojha')

# %% [markdown]
# ## **Variables and Names**

# %% [markdown]
# ## Creating Variables
#
# * Variables are containers for storing data values.
# * Unlike other programming languages, Python has no command for declaring a variable.
# * A variable is created the moment you first assign a value to it.

# %%
# int a = 10;
# float b = 3.2;
# char ch = 'a';


cars = 100
space_in_a_car = 4.0
drivers = 30
passengers = 90

cars_not_driven = cars - drivers #  100 - 30 = 70
cars_driven = drivers # 30
carpool_capacity = cars_driven * space_in_a_car # 30 * 4.0
average_passengers_per_car = passengers / cars_driven # 90 / 30

print("There are", cars, "cars available.")

print("There are only", drivers, "drivers available.")
print("There will be", cars_not_driven, "empty cars today.")
print("We can transport", carpool_capacity, "people today.")
print("We have", passengers, "to carpool today.")
print("We need to put about", average_passengers_per_car, "in each car.")
# Out:
# There are 100 cars available.
# There are only 30 drivers available.
# There will be 70 empty cars today.
# We can transport 120.0 people today.
# We have 90 to carpool today.
# We need to put about 3.0 in each car.

# %% [markdown]
# * Variables do not need to be declared with any particular type and can even change type after they have been set.

# %%
x = 4 # x is of type int
print(x)

x = "Sally" # x is now of type str
print(x)
# Out:
# 4
# Sally

# %% [markdown]
# ## Variable Names
# A variable can have a short name (like x and y) or a more descriptive name (age, carname, total_volume).
#
# Rules for Python variables:
# * A variable name must start with a letter or the underscore character
# * A variable name cannot start with a number
# * A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
# * Variable names are case-sensitive (age, Age and AGE are three different variables)

# %%
#Legal variable names:
myvar = "John"
my_var = "John"
_my_var = "John"
myVar = "John"
MYVAR = "John"
myvar2 = "John"

#Illegal variable names:
2myvar = "John"
my-var = "John"
my var = "John"

# %% [markdown]
# **Remember that variable names are case-sensitive**

# %% [markdown]
# ## Assign Value to Multiple Variables
#
# Python allows you to assign values to multiple variables in one line:

# %%
a = 20
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %% [markdown]
# # **Formatted Printing**
#
# [Python Docs](https://docs.python.org/3/tutorial/inputoutput.html)

# %% [markdown]
# Every time you put `"` (double-quotes) or `'` (single-quote) around a piece of text you have been making a string.

# %%
my_name = 'Zed A. Shaw'
my_age = 35 # not a lie
my_height = 74 # inches
my_weight = 180 # lbs
my_eyes = 'Blue'
my_teeth = 'White'
my_hair = 'Brown'

print(f"Let's talk about {my_name}.")

print(f"He's {my_height} inches tall.")
print(f"He's {my_weight} pounds heavy.")

print("Actually that's not too heavy.")

print(f"He's got {my_eyes} eyes and {my_hair} hair.")

print(f"His teeth are usually {my_teeth} depending on the coffee.")

# this line is tricky, try to get it exactly right
total = my_age + my_height + my_weight

print(f"If I add {my_age}, {my_height}, and {my_weight} I get {total}.")
# Out:
# Let's talk about Zed A. Shaw.
# He's 74 inches tall.
# He's 180 pounds heavy.
# Actually that's not too heavy.
# He's got Blue eyes and Brown hair.
# His teeth are usually White depending on the coffee.
# If I add 35, 74, and 180 I get 289.

# %% [markdown]
# You embed variables inside a string by using a special {} sequence and then put the variable you want inside the {} characters.
#
# You also must start the string with the letter f for “format,” as in f"Hello {somevariable}".
#
# This letter f before the " (double-quote) and the {} characters tell
# Python 3, “this string needs to be formatted. Put these variables in there.”

# %%
# types_of_people = 10

# x = f"There are {types_of_people} types of people."

# # print("%s  and %s", "Me", "Myself") In C language
# # mystr = "%s  and %s", "Me", "Myself"

# binary = "binary"
# do_not = "don't"
# y = f"Those who know {binary} and those who {do_not}."

# print(x)
# print(y)

# print(f"I said: {x}")
# print(f"I also said: '{y}'")

hilarious = False
joke_evaluation = "Isn't that joke so funny?! {}"

# Python also has another kind of formatting using the .format() syntax
# that is used when we want to apply a format to an already-created string
print(joke_evaluation.format(hilarious))


# w = "This is the left side of..."
# e = "a string with a right side."
# print(w + e)
# Out:
# Isn't that joke so funny?! False

# %%
# # print("Mary had a little lamb.")


# myString = "Its fleece was white as {}."
# color = 'snow'

# print(myString.format(color))

# print("And everywhere that Mary went.")

# print(2 * 10)
print("." * 10) # what'd that do?

# end1 = "C"
# end2 = "h"
# end3 = "e"
# end4 = "e"
# end5 = "s"
# end6 = "e"
# end7 = "B"
# end8 = "u"
# end9 = "r"
# end10 = "g"
# end11 = "e"
# end12 = "r"


# # ',' sign puts a space between two values being printed
# print(end1 , end2 , end3 , end4 , end5 , end6)
# # '+' sign does not space between two values being printed
print(end1 + end2 + end3 + end4 + end5 + end6, end=",")
print("\n", end7 + end8 + end9 + end10 + end11 + end12)

# We put an end=" " at the end of line. This tells print to not end
# the line with a newline character and go to the next line.
# Out:
# ..........
# Cheese
#
#  Burger

# %% [markdown]
# **Why are you using the variable named 'snow'?**
#
# > That’s actually not a variable: it is just a string with
# the word snow in it. A variable wouldn’t have the single-quotes around it.
#
# **Is it normal to write an English comment for every line of code like you say to do in Study Drill 1?**
#
# > No, you write comments only to explain difficult-to-understand code or why you did something.
#
# > Why is usually much more important, and then you try to write the code so that it explains how something is being done on its own. However, sometimes you have to write such nasty code to solve a problem that it does need a comment on every line.
#
# > In this case it’s strictly for you to practice translating code to English.
#
#
# **Can I use single-quotes or double-quotes to make a string or do they do different things?**
#
# > In Python either way to make a string is acceptable, although typically you’ll use single-quotes for any short strings like 'a' or 'snow'.

# %%
import math
print(f'The value of pi is approximately {math.pi:.3f}.')

print(f'{"Jack":10} ==> {1122334455:10d}')
print(f'{"MuneendraO":10} ==> {2233551155:10d}')
# Out:
# The value of pi is approximately 3.142.
# Jack       ==> 1122334455
# MuneendraO ==> 2233551155

# %%
formatter = "{} {} {} {}"
			
# print(formatter.format(1,	2,	3,	4))
# print(formatter.format("one","two",	"three", "four"))
# print(formatter.format(True,	False,	False,	True))
# print(formatter.format(formatter, formatter,	formatter,	formatter))
# print(formatter.format("Try your",
#                        "Own text here",
#                        "Maybe a poem",
#                        "Or a song about fear")
# )
# Out:
# one two three four
# Try your Own text here Maybe a poem Or a song about fear

# %%
message = '''The price of this
                {0:s} laptop is 
                {1:d} USD and the exchange rate is 
                {2:4.2f} USD to 1 EUR'''.format('Apple', 1299, 1.235235245)
print(message)
# Out:
# The price of this
#                 Apple laptop is
#                 1299 USD and the exchange rate is
#                 1.24 USD to 1 EUR

# %% [markdown]
# **Why do I have to put quotes around "one" but not around True or False?**
#
# > Python recognizes True and False as keywords representing the concept of true and false. If you put quotes
# around them then they are turned into strings and won’t work.

# %%
# Here's some new strange stuff, remember type it exactly.
days = "Mon Tue Wed Thu Fri Sat Sun"
months = "Jan\nFeb\nMar\nApr\nMay\nJun\nJul\nAug"
print("Here are the days: ", days)
print("Here are the months: ", months)
print("""
There's something going on here.
With the three double-quotes.
We'll be able to type as much as we like.
Even 4 lines if we want, or 5, or 6.
""")
# Out:
# Here are the days:  Mon Tue Wed Thu Fri Sat Sun
# Here are the months:  Jan
# Feb
# Mar
# Apr
# May
# Jun
# Jul
# Aug
#
# There's something going on here.
# With the three double-quotes.
# We'll be able to type as much as we like.
# Even 4 lines if we want, or 5, or 6.

# %%
tabby_cat = "\tI'm tabbed in."
persian_cat = "I'm split\non a line."
backslash_cat = "I'm \\ a \\ cat."

fat_cat = """
I'll do a list:
\t* Cat food
\t* Fishies
\t* Catnip\n\t* Grass
"""

print(tabby_cat)
print(persian_cat)
print(backslash_cat)
print(fat_cat)
# Out:
# 	I'm tabbed in.
# I'm split
# on a line.
# I'm \ a \ cat.
#
# I'll do a list:
# 	* Cat food
# 	* Fishies
# 	* Catnip
# 	* Grass

# %% [markdown]
# **Why do I get an error when I put spaces between the three double-quotes?**
#
# > You have to type them like """ and not " " ", meaning with no spaces between each one.
#
#
# **What if I wanted to start the months on a new line?**
#
# > You simply start the string with \n, like this:
#
# > "\nJan\nFeb\nMar\nApr\nMay\nJun\nJul\nAug"
#
#
# **Is it bad that my errors are always spelling mistakes?**
#
# > Most programming errors in the beginning (and even later) are simple spelling mistakes, typos, or getting simple things out of order.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Taking input from user**
#
# ## `input()`

# %% [markdown]
# Most of what software does is the following:
# 1. Takes some kind of input from a person.
# 2. Changes it.
# 3. Prints out something to show how it changed.

# %%
print("How old are you?", end=' ')
age = input() # Right hand side is replaced with the value entered by the user
print("How tall are you?", end=' ')
height = input()
print("How much do you weigh?", end=' ')
weight = input()
print(f"So, you're {age} old, {height} tall and {weight} heavy.")
# Out:
# How old are you? 10
# How tall are you? 20
# How much do you weigh? 30
# So, you're 10 old, 20 tall and 30 heavy.

# %% [markdown]
# For input you can also put in a message to show to a person so he knows what to type.
#
# > `y = input("Name? ")`
#
# This prompts the user with “Name?” and puts the result into the variable y.

# %%
age = input("How old are you? ")
height = input("How tall are you? ")
weight = input("How much do you weigh? ")
print(f"So, you're {age} old, {height} tall and {weight} heavy.")
# Out:
# How old are you? 10
# How tall are you? 20
# How much do you weigh? 30
# So, you're 10 old, 20 tall and 30 heavy.

# %% [markdown]
# # **Numbers and Math**

# %% [markdown]
# Math symbols
#
# * `+` : plus
# * `-` : minus
# * `/` : slash
# * `*` : asterisk
# * `%` : percent
# * `<` : less-than
# * `>` : greater-than
# * `<=` : less-than-equal
# * `>=`: greater-than-equal

# %%
print("I will now count my chickens:")
print("Hens", 25 + 30 / 6)
print("Roosters", 100 - 25 * 3 % 4)

print("Now I will count the eggs:")
print(3 + 2 + 1 - 5 + 4 % 2 - 1 / 4 + 6)
print("Is it true that 3 + 2 < 5 - 7?")
print(3 + 2 < 5 - 7)
print("What is 3 + 2?", 3 + 2)
print("What is 5 - 7?", 5 - 7)
print("Oh, that's why it's False.")
# Out:
# I will now count my chickens:
# Hens 30.0
# Roosters 97
# Now I will count the eggs:
# 6.75
# Is it true that 3 + 2 < 5 - 7?
# False
# What is 3 + 2? 5
# What is 5 - 7? -2
# Oh, that's why it's False.

# %%
print("How about some more.")
print("Is it greater?", 5 > -2)
print("Is it greater or equal?", 5 >= -2)
print("Is it less or equal?", 5 <= -2)
# Out:
# How about some more.
# Is it greater? True
# Is it greater or equal? True
# Is it less or equal? False

# %% [markdown]
# # **Practice Examples**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
firstname = input("Please enter your first name: ") print ("Hello",firstname)
# Out:
#   File "<ipython-input-61-ab258940c4af>", line 1
#     firstname = input("Please enter your first name: ") print ("Hello",firstname)
#                                                             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
firstname = input("Please enter your first name: ") surname = input("Please enter your surname: ") print ("Hello",firstname, surname)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("What do you call a bear with no teeth?\nA gummy bear!")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
numl = int(input("Please enter your first number: ")) num2 = int(input("Please enter your second number: ")) answer = numl + num2 print("The answer is", answer)
# Out:
#   File "<ipython-input-62-d367cf07e146>", line 1
#     numl = int(input("Please enter your first number: ")) num2 = int(input("Please enter your second number: ")) answer = numl + num2 print("The answer is", answer)
#                                                              ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
numl = int(input("Please enter your first number: ")) num2 = int(input("Please enter your second number: ")) num3 = int(input("Please enter answer = (numl + num2)* num3 print("The answer is", answer) your third number: "))
# Out:
#   File "<ipython-input-63-8d780edb4725>", line 1
#     numl = int(input("Please enter your first number: ")) num2 = int(input("Please enter your second number: ")) num3 = int(input("Please enter answer = (numl + num2)* num3 print("The answer is", answer) your third number: "))
#                                                              ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
startNum = int(input("Enter the number of slices of pizza you started with: ")) endNum = int(input("How many slices have you eaten? ")) slicesLeft = startNum - endNum print("You have", slicesLeft, "slices remaining")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
name = input("What is your name? ") age = int(input("How old are you? ")) newAge = age + 1 print(name, "next birthday you will be", newAge)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
bill = int(input("What is the total cost of the bill? ")) people = int(input("How many people are there? ")) each = bill/people print("Each person should pay £", each)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
days = int(input("Enter the number of days: ")) hours = days*24 minutes = hours*60 seconds = minutes*60 print("In", days,"days there are...") print(hours, "hours") print(minutes, "minutes") print(seconds, "seconds")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
kilo = int(input("Enter the number of kilos: ")) pound = kilo * 2.204 print("That is", pound,"pounds")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
larger = int(input("Enter a number over 100: ")) smaller = int(input("Enter a number under 10: ")) answer = larger//smaller print(smaller,"goes into", larger, answer,"times")

# %% [markdown]
# ## A quick recapitulation

# %%
print("I will now count my chickens:") 
print("Hens", 25 + 30 / 6) print("Roosters", 100 - 25 * 3 % 4) 
print("Now I will count the eggs:") print(3 + 2 + 1 - 5 + 4 % 2 - 1 / 4 + 6) print("Is it true that 3 + 2 < 5 - 7?") print(3 + 2 < 5 - 7) print("What is 3 + 2?", 3 + 2) print("What is 5 - 7?", 5 - 7) print("Oh, that's why its False.") 
print("How about some more.") 
print("Is it greater?", 5 > -2) print("Is it greater or equal?", 5 >= -2) print("Is it less or equal?", 5 <= -2)

# %% [markdown]
# **Why do you put ' (single-quotes) around some strings and not others?**
#
# Mostly it’s because of style,
# but I’ll use a single-quote inside a string that has double-quotes. Look at lines 6 and 15 to
# see how I’m doing that.
